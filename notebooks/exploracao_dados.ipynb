# %% [markdown]
# <a href="https://colab.research.google.com/github/Santosdevbjj/recomendMusicasGrafos/blob/main/notebooks/exploracao_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('../data/raw/dataset_spotify.csv')
df.head()

df.groupby('genre')['listen_count'].sum()
